# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

import sys
sys.path.append('/content/gdrive/My Drive/python/csearch')
import csearch
# Out:
# Mounted at /content/gdrive
# initializing csearch
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Done

# %%
# %csearch -h
# Out:
# usage: ipykernel_launcher.py [-h] [-l] [-r] [-t TAGS [TAGS ...]]
#                              [-f FUNCTION [FUNCTION ...]]
#                              [-m MARKDOWN [MARKDOWN ...]] [-c CODE [CODE ...]]
#                              [-p PROPERTY [PROPERTY ...]] [-d TODO [TODO ...]]
#                              [-H HEADING [HEADING ...]]
#                              [root] [pattern]
#
# Search Jupyter Notebooks
#
# positional arguments:
#   root                  Root directory to search in.
#   pattern               Pattern to search for.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -l, --list            list all notebooks
#   -r, --recursive       search recursively
#   -t TAGS [TAGS ...], --tags TAGS [TAGS ...]
#                         Search for tags
#   -f FUNCTION [FUNCTION ...], --function FUNCTION [FUNCTION ...]
#                         Search using a predicate function
# ...

# %% [markdown]
# # Get links to all notebooks

# %%
# %csearch "My Drive/python/csearch" -lr
# Out:
# <a href=https://colab.research.google.com/drive/18LGMrJwKbAarHR36wWXZHHD-kS9Hblei target=_blank>/content/gdrive/My Drive/python/csearch/examples.ipynb</a>
# <a href=https://colab.research.google.com/drive/1rR9zMvFbXLPlLZByTTLaGx0OblhskSfQ target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/tags-1.ipynb</a>
# <a href=https://colab.research.google.com/drive/1iqFVvaMR-Ee1ChOhz-VmW386-WDPITqj target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/tags-2.ipynb</a>
# <a href=https://colab.research.google.com/drive/1xtYbIxVIk5CxPBPPALDERjTKDTpmOLsI target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/properties-1.ipynb</a>
# <a href=https://colab.research.google.com/drive/1puHgw-24w0Q02UJ-JJKlZ8zNUdVeJ07a target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/headings.ipynb</a>
# ...

# %% [markdown]
# # search Markdown

# %%
# %csearch "My Drive/python/csearch" -r -m independent
# Out:
# <a href=https://colab.research.google.com/drive/1puHgw-24w0Q02UJ-JJKlZ8zNUdVeJ07a target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/headings.ipynb</a>

# %% [markdown]
# # Search code

# %%
# %csearch "My Drive/python/csearch" -r -c independent
# Out:
# <a href=https://colab.research.google.com/drive/18LGMrJwKbAarHR36wWXZHHD-kS9Hblei target=_blank>/content/gdrive/My Drive/python/csearch/examples.ipynb</a>

# %% [markdown]
# # search tags

# %%
# %csearch "My Drive/python/csearch" -r -t tag1
# Out:
# <a href=https://colab.research.google.com/drive/1rR9zMvFbXLPlLZByTTLaGx0OblhskSfQ target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/tags-1.ipynb</a>
# <a href=https://colab.research.google.com/drive/19bSBE3bxmStoLgIhzCpoGCT1PyWIn7LT target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/heading+tag1.ipynb</a>

# %%
# %csearch "My Drive/python/csearch" -r -t !tag1 tag2
# Out:
# <a href=https://colab.research.google.com/drive/1iqFVvaMR-Ee1ChOhz-VmW386-WDPITqj target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/tags-2.ipynb</a>

# %% [markdown]
# # Search properties

# %%
# %csearch "My Drive/python/csearch" -r -p author=jkitchin
# Out:
# <a href=https://colab.research.google.com/drive/1xtYbIxVIk5CxPBPPALDERjTKDTpmOLsI target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/properties-1.ipynb</a>

# %% [markdown]
# # Search headings

# %%
# %csearch "My Drive/python/csearch" -r -H tags
# Out:
# <a href=https://colab.research.google.com/drive/18LGMrJwKbAarHR36wWXZHHD-kS9Hblei target=_blank>/content/gdrive/My Drive/python/csearch/examples.ipynb</a>

# %% [markdown]
# # Search todo

# %%
# %csearch "My Drive/python/csearch" -r -d leading
# Out:
#   % todo even with leading spaces should be ok
# <a href=https://colab.research.google.com/drive/1C67-9ssV2uV-BnpJ_-5cZNQRnL-nPvKF target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/todo.ipynb</a>

# %%
# %csearch "My Drive/python/csearch" -r -d due
# Out:
# %todo line todo with no duedate
# <a href=https://colab.research.google.com/drive/1C67-9ssV2uV-BnpJ_-5cZNQRnL-nPvKF target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/todo.ipynb</a>
# % todo [2020-08-29] todo with a due date and an extra space
# <a href=https://colab.research.google.com/drive/1C67-9ssV2uV-BnpJ_-5cZNQRnL-nPvKF target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/todo.ipynb</a>
# %  todo no due date, but several spaces
# <a href=https://colab.research.google.com/drive/1C67-9ssV2uV-BnpJ_-5cZNQRnL-nPvKF target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/todo.ipynb</a>
# %% todo a title but no due date
# <a href=https://colab.research.google.com/drive/1C67-9ssV2uV-BnpJ_-5cZNQRnL-nPvKF target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/todo.ipynb</a>
# %% todo [2020-09-01] duedate and a title
# ...

# %% [markdown]
# # Combine criteria

# %% [markdown]
# ## A simple query with just tags gets two results

# %%
# %csearch "My Drive/python/csearch" -r -t tag1
# Out:
# <a href=https://colab.research.google.com/drive/1rR9zMvFbXLPlLZByTTLaGx0OblhskSfQ target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/tags-1.ipynb</a>
# <a href=https://colab.research.google.com/drive/19bSBE3bxmStoLgIhzCpoGCT1PyWIn7LT target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/heading+tag1.ipynb</a>

# %% [markdown]
# ## Narrow with multiple criteria

# %%
# %csearch "My Drive/python/csearch" -r -t tag1 -H heading
# Out:
# <a href=https://colab.research.google.com/drive/19bSBE3bxmStoLgIhzCpoGCT1PyWIn7LT target=_blank>/content/gdrive/My Drive/python/csearch/csearch/examples/heading+tag1.ipynb</a>
